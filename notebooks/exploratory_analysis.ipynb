# %% [markdown]
# # Exploratory Analysis\nThis notebook is a starter for inspecting run outputs from `outputs/runs/<run_id>`.

# %%
from pathlib import Path\nimport pandas as pd\n\nrun_dir = Path('outputs/runs')\nprint('Run root exists:', run_dir.exists())
